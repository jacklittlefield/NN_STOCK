# %%
#workflow for setting up my dataframes:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime

# %%
df = pd.read_csv('APRN.csv')

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2017-06-29  10.00  11.00  10.00  10.00      10.00  41055400
# 1  2017-06-30   9.98  10.10   9.17   9.34       9.34  12405100
# 2  2017-07-03   9.48   9.67   8.88   9.67       9.67   4270500
# 3  2017-07-05   9.60   9.63   8.78   8.84       8.84   5103800
# 4  2017-07-06   8.83   8.84   7.95   8.06       8.06  12546900

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
#df.drop('date', axis = 1, inplace=True)

# %%
df.head()
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0 2017-06-29  10.00  11.00  10.00  10.00      10.00  41055400
# 1 2017-06-30   9.98  10.10   9.17   9.34       9.34  12405100
# 2 2017-07-03   9.48   9.67   8.88   9.67       9.67   4270500
# 3 2017-07-05   9.60   9.63   8.78   8.84       8.84   5103800
# 4 2017-07-06   8.83   8.84   7.95   8.06       8.06  12546900

# %%
df.set_index(df['Date'], inplace=True)

# %%
plt.plot(df['Close']);

# %%
df['std'] = df['Adj Close'].rolling(20).std()

# %%
df.tail()
# Out:
#                  Date  Open  High   Low  Close  Adj Close   Volume       std
# Date
# 2018-10-10 2018-10-10  1.40  1.43  1.31   1.34       1.34  3903800  0.172477
# 2018-10-11 2018-10-11  1.31  1.42  1.29   1.30       1.30  4465100  0.180592
# 2018-10-12 2018-10-12  1.33  1.40  1.32   1.34       1.34  2896800  0.183601
# 2018-10-15 2018-10-15  1.35  1.38  1.32   1.35       1.35  1141500  0.185837
# 2018-10-16 2018-10-16  1.38  1.42  1.33   1.35       1.35  4082700  0.187248

# %%
df['upper'] = df['Close'] + (df['std']*2)
df['lower'] = df['Close'] - (df['std']*2)

# %%
df.head()
# Out:
#                  Date   Open   High    Low  Close  Adj Close    Volume  std  \
# Date
# 2017-06-29 2017-06-29  10.00  11.00  10.00  10.00      10.00  41055400  NaN
# 2017-06-30 2017-06-30   9.98  10.10   9.17   9.34       9.34  12405100  NaN
# 2017-07-03 2017-07-03   9.48   9.67   8.88   9.67       9.67   4270500  NaN
# 2017-07-05 2017-07-05   9.60   9.63   8.78   8.84       8.84   5103800  NaN
# 2017-07-06 2017-07-06   8.83   8.84   7.95   8.06       8.06  12546900  NaN
#
#             upper  lower
# Date
# 2017-06-29    NaN    NaN
# 2017-06-30    NaN    NaN
# 2017-07-03    NaN    NaN
# 2017-07-05    NaN    NaN
# 2017-07-06    NaN    NaN

# %%
plt.figure(figsize=(25,10))
plt.plot(df['Close'])
plt.plot(df['upper'])
plt.plot(df['lower'])
plt.legend();

# %%
plt.figure(figsize=(20,10))
plt.plot(df['std']);

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Volume']);

# %%
df.tail()
# Out:
#                  Date  Open  High   Low  Close  Adj Close   Volume       std  \
# Date
# 2018-10-10 2018-10-10  1.40  1.43  1.31   1.34       1.34  3903800  0.172477
# 2018-10-11 2018-10-11  1.31  1.42  1.29   1.30       1.30  4465100  0.180592
# 2018-10-12 2018-10-12  1.33  1.40  1.32   1.34       1.34  2896800  0.183601
# 2018-10-15 2018-10-15  1.35  1.38  1.32   1.35       1.35  1141500  0.185837
# 2018-10-16 2018-10-16  1.38  1.42  1.33   1.35       1.35  4082700  0.187248
#
#                upper     lower
# Date
# 2018-10-10  1.684955  0.995045
# 2018-10-11  1.661184  0.938816
# 2018-10-12  1.707203  0.972797
# 2018-10-15  1.721675  0.978325
# 2018-10-16  1.724496  0.975504

# %%
df.drop(['Open', 'High', 'Low', 'Adj Close', 'Date'], axis = 1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
#df.drop('Date', axis =1, inplace=True)

# %%
df.head()
# Out:
#             Close   Volume       std     upper     lower
# Date
# 2017-07-27   6.72  2106900  1.093254  8.906509  4.533491
# 2017-07-28   6.74  1938300  0.952881  8.645762  4.834238
# 2017-07-31   6.61  1396400  0.859029  8.328059  4.891941
# 2017-08-01   6.37  2117200  0.681454  7.732907  5.007093
# 2017-08-02   6.20  3832900  0.585847  7.371694  5.028306

# %%
df['Close'].min()
# Out:
# 1.3

# %%
rates = pd.read_csv('TB3MS.csv')

# %%
rates.head()
# Out:
#          DATE  TB3MS
# 0  1934-01-01   0.72
# 1  1934-02-01   0.62
# 2  1934-03-01   0.24
# 3  1934-04-01   0.15
# 4  1934-05-01   0.16

# %%
rates['Date'] = pd.to_datetime(rates['DATE'])

# %%
rates.set_index('Date', inplace=True)

# %%
rates.drop('DATE', axis=1, inplace=True)

# %%
names = {'TB3MS':'Rates'}

# %%
rates.rename(mapper=names, axis = 1, inplace=True)

# %%
rates
# Out:
#             Rates
# Date
# 1934-01-01   0.72
# 1934-02-01   0.62
# 1934-03-01   0.24
# 1934-04-01   0.15
# 1934-05-01   0.16
# 1934-06-01   0.15
# 1934-07-01   0.15
# 1934-08-01   0.19
# 1934-09-01   0.21
# 1934-10-01   0.27
# 1934-11-01   0.25
# 1934-12-01   0.23
# 1935-01-01   0.20
# 1935-02-01   0.19
# 1935-03-01   0.15
# 1935-04-01   0.15
# 1935-05-01   0.15
# 1935-06-01   0.15
# 1935-07-01   0.15
# 1935-08-01   0.16
# 1935-09-01   0.20
# 1935-10-01   0.20
# 1935-11-01   0.16
# 1935-12-01   0.15
# 1936-01-01   0.20
# 1936-02-01   0.20
# 1936-03-01   0.20
# 1936-04-01   0.20
# 1936-05-01   0.20
# 1936-06-01   0.20
# ...           ...
# 2016-03-01   0.29
# 2016-04-01   0.23
# 2016-05-01   0.27
# 2016-06-01   0.27
# 2016-07-01   0.30
# 2016-08-01   0.30
# 2016-09-01   0.29
# 2016-10-01   0.33
# 2016-11-01   0.45
# 2016-12-01   0.51
# 2017-01-01   0.51
# 2017-02-01   0.52
# 2017-03-01   0.74
# 2017-04-01   0.80
# 2017-05-01   0.89
# 2017-06-01   0.98
# 2017-07-01   1.07
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(rates);

# %%
comb = pd.concat((df, rates), axis=1)

# %%
comb.head()
# Out:
#             Close  Volume  std  upper  lower  Rates
# Date
# 1934-01-01    NaN     NaN  NaN    NaN    NaN   0.72
# 1934-02-01    NaN     NaN  NaN    NaN    NaN   0.62
# 1934-03-01    NaN     NaN  NaN    NaN    NaN   0.24
# 1934-04-01    NaN     NaN  NaN    NaN    NaN   0.15
# 1934-05-01    NaN     NaN  NaN    NaN    NaN   0.16

# %%
comb['Rates'] = comb['Rates'].fillna(method='ffill')

# %%
comb.tail()
# Out:
#             Close     Volume       std     upper     lower  Rates
# Date
# 2018-10-10   1.34  3903800.0  0.172477  1.684955  0.995045   2.03
# 2018-10-11   1.30  4465100.0  0.180592  1.661184  0.938816   2.03
# 2018-10-12   1.34  2896800.0  0.183601  1.707203  0.972797   2.03
# 2018-10-15   1.35  1141500.0  0.185837  1.721675  0.978325   2.03
# 2018-10-16   1.35  4082700.0  0.187248  1.724496  0.975504   2.03

# %%
comb.dropna(inplace=True)

# %%
comb.head()
# Out:
#             Close     Volume       std     upper     lower  Rates
# Date
# 2017-07-27   6.72  2106900.0  1.093254  8.906509  4.533491   1.07
# 2017-07-28   6.74  1938300.0  0.952881  8.645762  4.834238   1.07
# 2017-07-31   6.61  1396400.0  0.859029  8.328059  4.891941   1.07
# 2017-08-01   6.37  2117200.0  0.681454  7.732907  5.007093   1.01
# 2017-08-02   6.20  3832900.0  0.585847  7.371694  5.028306   1.01

# %%
plt.figure(figsize=(20,10))
plt.plot(comb[['Rates', 'Close']]);

# %%
comb.to_csv('aprn_rates_nonadj.csv', index=True, header=True, date_format='%Y-%m-%d')

# %%
feats = pd.read_csv('aprn_rates_nonadj.csv')

# %%
feats.head()
# Out:
#          Date  Close     Volume       std     upper     lower  Rates
# 0  2017-07-27   6.72  2106900.0  1.093254  8.906509  4.533491   1.07
# 1  2017-07-28   6.74  1938300.0  0.952881  8.645762  4.834238   1.07
# 2  2017-07-31   6.61  1396400.0  0.859029  8.328059  4.891941   1.07
# 3  2017-08-01   6.37  2117200.0  0.681454  7.732907  5.007093   1.01
# 4  2017-08-02   6.20  3832900.0  0.585847  7.371694  5.028306   1.01

# %%
feats['Date'] = pd.to_datetime(feats['Date'])

# %%
feats.head()
# Out:
#         Date  Close     Volume       std     upper     lower  Rates
# 0 2017-07-27   6.72  2106900.0  1.093254  8.906509  4.533491   1.07
# 1 2017-07-28   6.74  1938300.0  0.952881  8.645762  4.834238   1.07
# 2 2017-07-31   6.61  1396400.0  0.859029  8.328059  4.891941   1.07
# 3 2017-08-01   6.37  2117200.0  0.681454  7.732907  5.007093   1.01
# 4 2017-08-02   6.20  3832900.0  0.585847  7.371694  5.028306   1.01

# %%
#for i in feats['Date']:
    #print("%M")
