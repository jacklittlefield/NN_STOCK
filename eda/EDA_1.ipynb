# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('GE.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
df['Lag'] = df['Close'].shift(5)[6000:]

# %%
df.set_index('Date', inplace=True)

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# Lag          float64
# dtype: object

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Close'])
plt.plot(df['Adj Close'])
plt.legend();
