# %%
#workflow for setting up my dataframes:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime

# %%
def make_csv('input'):
    df =

# %%
df = pd.read_csv('GE.csv')

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1990-10-01  4.541667  4.708333  4.541667  4.687500   0.395499   9996000
# 1  1990-10-02  4.729167  4.781250  4.635417  4.645833   0.391983  29752800
# 2  1990-10-03  4.614583  4.697917  4.520833  4.541667   0.383194  16078800
# 3  1990-10-04  4.479167  4.583333  4.447917  4.531250   0.382316  19591200
# 4  1990-10-05  4.437500  4.635417  4.385417  4.520833   0.381437  23518800

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
#df.drop('date', axis = 1, inplace=True)

# %%
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume
# 0 1990-10-01  4.541667  4.708333  4.541667  4.687500   0.395499   9996000
# 1 1990-10-02  4.729167  4.781250  4.635417  4.645833   0.391983  29752800
# 2 1990-10-03  4.614583  4.697917  4.520833  4.541667   0.383194  16078800
# 3 1990-10-04  4.479167  4.583333  4.447917  4.531250   0.382316  19591200
# 4 1990-10-05  4.437500  4.635417  4.385417  4.520833   0.381437  23518800

# %%
df.set_index(df['Date'], inplace=True)

# %%
plt.plot(df['Close']);

# %%
df['std'] = df['Adj Close'].rolling(20).std()

# %%
df.tail()
# Out:
#                  Date   Open   High    Low  Close  Adj Close     Volume  \
# Date
# 2018-09-24 2018-09-24  12.10  12.10  11.60  11.74      11.74  148589900
# 2018-09-25 2018-09-25  11.73  11.76  11.22  11.27      11.27  133694200
# 2018-09-26 2018-09-26  11.25  11.56  11.21  11.39      11.39   93374600
# 2018-09-27 2018-09-27  11.37  11.75  11.36  11.53      11.53   82196200
# 2018-09-28 2018-09-28  11.44  11.51  11.25  11.29      11.29   76542900
#
#                  std
# Date
# 2018-09-24  0.268106
# 2018-09-25  0.383368
# 2018-09-26  0.446212
# 2018-09-27  0.470152
# 2018-09-28  0.515216

# %%
df['upper'] = df['Close'] + (df['std']*2)
df['lower'] = df['Close'] - (df['std']*2)

# %%
plt.figure(figsize=(20,10))
plt.plot(df[['Close', 'upper', 'lower']]);

# %%
plt.figure(figsize=(20,10))
plt.plot(df['std']);

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Volume']);

# %%
df.tail()
# Out:
#                  Date   Open   High    Low  Close  Adj Close     Volume  \
# Date
# 2018-09-24 2018-09-24  12.10  12.10  11.60  11.74      11.74  148589900
# 2018-09-25 2018-09-25  11.73  11.76  11.22  11.27      11.27  133694200
# 2018-09-26 2018-09-26  11.25  11.56  11.21  11.39      11.39   93374600
# 2018-09-27 2018-09-27  11.37  11.75  11.36  11.53      11.53   82196200
# 2018-09-28 2018-09-28  11.44  11.51  11.25  11.29      11.29   76542900
#
#                  std      upper      lower
# Date
# 2018-09-24  0.268106  12.276213  11.203787
# 2018-09-25  0.383368  12.036737  10.503263
# 2018-09-26  0.446212  12.282424  10.497576
# 2018-09-27  0.470152  12.470304  10.589696
# 2018-09-28  0.515216  12.320433  10.259567

# %%
df.drop(['Open', 'High', 'Low', 'Adj Close', 'Date'], axis = 1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
#df.drop('Date', axis =1, inplace=True)

# %%
df.head()
# Out:
#                Close    Volume       std     upper     lower
# Date
# 1990-10-26  4.208333  23842800  0.011546  4.231424  4.185242
# 1990-10-29  4.239583  23887200  0.011211  4.262006  4.217160
# 1990-10-30  4.395833  27138000  0.010366  4.416565  4.375101
# 1990-10-31  4.333333  15692400  0.010172  4.353677  4.312989
# 1990-11-01  4.364583  18014400  0.009890  4.384362  4.344804

# %%
df['Close'].min()
# Out:
# 4.2083330000000005

# %%
rates = pd.read_csv('TB3MS.csv')

# %%
rates.head()
# Out:
#          DATE  TB3MS
# 0  1934-01-01   0.72
# 1  1934-02-01   0.62
# 2  1934-03-01   0.24
# 3  1934-04-01   0.15
# 4  1934-05-01   0.16

# %%
rates['Date'] = pd.to_datetime(rates['DATE'])

# %%
rates.set_index('Date', inplace=True)

# %%
rates.drop('DATE', axis=1, inplace=True)

# %%
names = {'TB3MS':'Rates'}

# %%
rates.rename(mapper=names, axis = 1, inplace=True)

# %%
rates
# Out:
#             Rates
# Date
# 1934-01-01   0.72
# 1934-02-01   0.62
# 1934-03-01   0.24
# 1934-04-01   0.15
# 1934-05-01   0.16
# 1934-06-01   0.15
# 1934-07-01   0.15
# 1934-08-01   0.19
# 1934-09-01   0.21
# 1934-10-01   0.27
# 1934-11-01   0.25
# 1934-12-01   0.23
# 1935-01-01   0.20
# 1935-02-01   0.19
# 1935-03-01   0.15
# 1935-04-01   0.15
# 1935-05-01   0.15
# 1935-06-01   0.15
# 1935-07-01   0.15
# 1935-08-01   0.16
# 1935-09-01   0.20
# 1935-10-01   0.20
# 1935-11-01   0.16
# 1935-12-01   0.15
# 1936-01-01   0.20
# 1936-02-01   0.20
# 1936-03-01   0.20
# 1936-04-01   0.20
# 1936-05-01   0.20
# 1936-06-01   0.20
# ...           ...
# 2016-03-01   0.29
# 2016-04-01   0.23
# 2016-05-01   0.27
# 2016-06-01   0.27
# 2016-07-01   0.30
# 2016-08-01   0.30
# 2016-09-01   0.29
# 2016-10-01   0.33
# 2016-11-01   0.45
# 2016-12-01   0.51
# 2017-01-01   0.51
# 2017-02-01   0.52
# 2017-03-01   0.74
# 2017-04-01   0.80
# 2017-05-01   0.89
# 2017-06-01   0.98
# 2017-07-01   1.07
# 2017-08-01   1.01
# 2017-09-01   1.03
# 2017-10-01   1.07
# 2017-11-01   1.23
# 2017-12-01   1.32
# 2018-01-01   1.41
# 2018-02-01   1.57
# 2018-03-01   1.70
# 2018-04-01   1.76
# 2018-05-01   1.86
# 2018-06-01   1.90
# 2018-07-01   1.96
# 2018-08-01   2.03
#
# [1016 rows x 1 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(rates);

# %%
comb = pd.concat((df, rates), axis=1)

# %%
comb.head()
# Out:
#             Close  Volume  std  upper  lower  Rates
# Date
# 1934-01-01    NaN     NaN  NaN    NaN    NaN   0.72
# 1934-02-01    NaN     NaN  NaN    NaN    NaN   0.62
# 1934-03-01    NaN     NaN  NaN    NaN    NaN   0.24
# 1934-04-01    NaN     NaN  NaN    NaN    NaN   0.15
# 1934-05-01    NaN     NaN  NaN    NaN    NaN   0.16

# %%
comb['Rates'] = comb['Rates'].fillna(method='ffill')

# %%
comb.tail()
# Out:
#             Close       Volume       std      upper      lower  Rates
# Date
# 2018-09-24  11.74  148589900.0  0.268106  12.276213  11.203787   2.03
# 2018-09-25  11.27  133694200.0  0.383368  12.036737  10.503263   2.03
# 2018-09-26  11.39   93374600.0  0.446212  12.282424  10.497576   2.03
# 2018-09-27  11.53   82196200.0  0.470152  12.470304  10.589696   2.03
# 2018-09-28  11.29   76542900.0  0.515216  12.320433  10.259567   2.03

# %%
comb.dropna(inplace=True)

# %%
comb.head()
# Out:
#                Close      Volume       std     upper     lower  Rates
# Date
# 1990-10-26  4.208333  23842800.0  0.011546  4.231424  4.185242   7.17
# 1990-10-29  4.239583  23887200.0  0.011211  4.262006  4.217160   7.17
# 1990-10-30  4.395833  27138000.0  0.010366  4.416565  4.375101   7.17
# 1990-10-31  4.333333  15692400.0  0.010172  4.353677  4.312989   7.17
# 1990-11-01  4.364583  18014400.0  0.009890  4.384362  4.344804   7.06

# %%
plt.figure(figsize=(20,10))
plt.plot(comb[['Rates', 'Close']]);

# %%
comb.to_csv('ge_rates_nonadj.csv', index=True, header=True, date_format='%Y-%m-%d')

# %%
feats = pd.read_csv('ge_rates_nonadj.csv')

# %%
feats.head()
# Out:
#          Date     Close      Volume       std     upper     lower  Rates
# 0  1990-10-26  4.208333  23842800.0  0.011546  4.231424  4.185242   7.17
# 1  1990-10-29  4.239583  23887200.0  0.011211  4.262006  4.217160   7.17
# 2  1990-10-30  4.395833  27138000.0  0.010366  4.416565  4.375101   7.17
# 3  1990-10-31  4.333333  15692400.0  0.010172  4.353677  4.312989   7.17
# 4  1990-11-01  4.364583  18014400.0  0.009890  4.384362  4.344804   7.06

# %%
feats['Date'] = pd.to_datetime(feats['Date'])

# %%
feats.head()
# Out:
#         Date     Close      Volume       std     upper     lower  Rates
# 0 1990-10-26  4.208333  23842800.0  0.011546  4.231424  4.185242   7.17
# 1 1990-10-29  4.239583  23887200.0  0.011211  4.262006  4.217160   7.17
# 2 1990-10-30  4.395833  27138000.0  0.010366  4.416565  4.375101   7.17
# 3 1990-10-31  4.333333  15692400.0  0.010172  4.353677  4.312989   7.17
# 4 1990-11-01  4.364583  18014400.0  0.009890  4.384362  4.344804   7.06

# %%
#for i in feats['Date']:
    #print("%M")
