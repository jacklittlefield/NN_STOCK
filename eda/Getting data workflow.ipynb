# %%
#workflow for setting up my dataframes:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime

# %%
df = pd.read_csv('GE.csv')

# %%
df.head()
# Out:
#        Date      Open      High       Low     Close  Adj Close    Volume
# 0  10/22/90  4.500000  4.531250  4.447917  4.479167   0.377921  31570800
# 1  10/23/90  4.468750  4.552083  4.468750  4.489583   0.378800  19628400
# 2  10/24/90  4.447917  4.458333  4.322917  4.322917   0.364738  29450400
# 3  10/25/90  4.354167  4.375000  4.229167  4.270833   0.360343  28003200
# 4  10/26/90  4.218750  4.239583  4.177083  4.208333   0.355070  23842800

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
#df.drop('date', axis = 1, inplace=True)

# %%
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume
# 0 1990-10-22  4.500000  4.531250  4.447917  4.479167   0.377921  31570800
# 1 1990-10-23  4.468750  4.552083  4.468750  4.489583   0.378800  19628400
# 2 1990-10-24  4.447917  4.458333  4.322917  4.322917   0.364738  29450400
# 3 1990-10-25  4.354167  4.375000  4.229167  4.270833   0.360343  28003200
# 4 1990-10-26  4.218750  4.239583  4.177083  4.208333   0.355070  23842800

# %%
df.set_index(df['Date'], inplace=True)

# %%
plt.plot(df['Close']);

# %%
df['std'] = df['Adj Close'].rolling(20).std()

# %%
df.tail()
# Out:
#                  Date   Open   High    Low  Close  Adj Close    Volume  \
# Date
# 2018-10-15 2018-10-15  12.25  12.50  12.14  12.15      12.15  62640200
# 2018-10-16 2018-10-16  12.23  12.29  12.00  12.10      12.10  86485800
# 2018-10-17 2018-10-17  12.25  12.56  12.12  12.19      12.19  83433100
# 2018-10-18 2018-10-18  12.14  12.43  12.06  12.38      12.38  81520200
# 2018-10-19 2018-10-19  12.28  12.73  12.26  12.56      12.56  86762800
#
#                  std
# Date
# 2018-10-15  0.709739
# 2018-10-16  0.709427
# 2018-10-17  0.700259
# 2018-10-18  0.699676
# 2018-10-19  0.700680

# %%
df['upper'] = df['Close'] + (df['std']*2)
df['lower'] = df['Close'] - (df['std']*2)

# %%
plt.figure(figsize=(20,10))
plt.plot(df[['Close', 'upper', 'lower']]);

# %%
plt.figure(figsize=(20,10))
plt.plot(df['std']);

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Volume']);

# %%
df.tail()
# Out:
#                  Date   Open   High    Low  Close  Adj Close    Volume  \
# Date
# 2018-10-15 2018-10-15  12.25  12.50  12.14  12.15      12.15  62640200
# 2018-10-16 2018-10-16  12.23  12.29  12.00  12.10      12.10  86485800
# 2018-10-17 2018-10-17  12.25  12.56  12.12  12.19      12.19  83433100
# 2018-10-18 2018-10-18  12.14  12.43  12.06  12.38      12.38  81520200
# 2018-10-19 2018-10-19  12.28  12.73  12.26  12.56      12.56  86762800
#
#                  std      upper      lower
# Date
# 2018-10-15  0.709739  13.569478  10.730522
# 2018-10-16  0.709427  13.518855  10.681145
# 2018-10-17  0.700259  13.590519  10.789481
# 2018-10-18  0.699676  13.779352  10.980648
# 2018-10-19  0.700680  13.961360  11.158640

# %%
df.drop(['Open', 'High', 'Low', 'Adj Close', 'Date'], axis = 1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
#df.drop('Date', axis =1, inplace=True)

# %%
df.head()
# Out:
#                Close    Volume       std     upper     lower
# Date
# 1990-11-16  4.614583  25172400  0.011162  4.636908  4.592258
# 1990-11-19  4.614583  18886800  0.011662  4.637906  4.591260
# 1990-11-20  4.437500  22634400  0.011617  4.460733  4.414267
# 1990-11-21  4.479167  15367200  0.011422  4.502011  4.456323
# 1990-11-23  4.468750   4462800  0.010901  4.490552  4.446948

# %%
df['Close'].min()
# Out:
# 4.3854169999999995

# %%
rates = pd.read_csv('TB3MS.csv')

# %%
rates.head()
# Out:
#          DATE  TB3MS
# 0  1934-01-01   0.72
# 1  1934-02-01   0.62
# 2  1934-03-01   0.24
# 3  1934-04-01   0.15
# 4  1934-05-01   0.16

# %%
rates['Date'] = pd.to_datetime(rates['DATE'])

# %%
rates.set_index('Date', inplace=True)

# %%
rates.drop('DATE', axis=1, inplace=True)

# %%
names = {'TB3MS':'Rates'}

# %%
rates.rename(mapper=names, axis = 1, inplace=True)

# %%
rates
# Out:
#             Rates
# Date
# 1934-01-01   0.72
# 1934-02-01   0.62
# 1934-03-01   0.24
# 1934-04-01   0.15
# 1934-05-01   0.16
# 1934-06-01   0.15
# 1934-07-01   0.15
# 1934-08-01   0.19
# 1934-09-01   0.21
# 1934-10-01   0.27
# 1934-11-01   0.25
# 1934-12-01   0.23
# 1935-01-01   0.20
# 1935-02-01   0.19
# 1935-03-01   0.15
# 1935-04-01   0.15
# 1935-05-01   0.15
# 1935-06-01   0.15
# 1935-07-01   0.15
# 1935-08-01   0.16
# 1935-09-01   0.20
# 1935-10-01   0.20
# 1935-11-01   0.16
# 1935-12-01   0.15
# 1936-01-01   0.20
# 1936-02-01   0.20
# 1936-03-01   0.20
# 1936-04-01   0.20
# 1936-05-01   0.20
# 1936-06-01   0.20
# ...           ...
# 2016-03-01   0.29
# 2016-04-01   0.23
# 2016-05-01   0.27
# 2016-06-01   0.27
# 2016-07-01   0.30
# 2016-08-01   0.30
# 2016-09-01   0.29
# 2016-10-01   0.33
# 2016-11-01   0.45
# 2016-12-01   0.51
# 2017-01-01   0.51
# 2017-02-01   0.52
# 2017-03-01   0.74
# 2017-04-01   0.80
# 2017-05-01   0.89
# 2017-06-01   0.98
# 2017-07-01   1.07
# 2017-08-01   1.01
# 2017-09-01   1.03
# 2017-10-01   1.07
# 2017-11-01   1.23
# 2017-12-01   1.32
# 2018-01-01   1.41
# 2018-02-01   1.57
# 2018-03-01   1.70
# 2018-04-01   1.76
# 2018-05-01   1.86
# 2018-06-01   1.90
# 2018-07-01   1.96
# 2018-08-01   2.03
#
# [1016 rows x 1 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(rates);

# %%
comb = pd.concat((df, rates), axis=1)

# %%
comb.head()
# Out:
#             Close  Volume  std  upper  lower  Rates
# Date
# 1934-01-01    NaN     NaN  NaN    NaN    NaN   0.72
# 1934-02-01    NaN     NaN  NaN    NaN    NaN   0.62
# 1934-03-01    NaN     NaN  NaN    NaN    NaN   0.24
# 1934-04-01    NaN     NaN  NaN    NaN    NaN   0.15
# 1934-05-01    NaN     NaN  NaN    NaN    NaN   0.16

# %%
comb['Rates'] = comb['Rates'].fillna(method='ffill')

# %%
comb.tail()
# Out:
#             Close      Volume       std      upper      lower  Rates
# Date
# 2018-10-15  12.15  62640200.0  0.709739  13.569478  10.730522   2.03
# 2018-10-16  12.10  86485800.0  0.709427  13.518855  10.681145   2.03
# 2018-10-17  12.19  83433100.0  0.700259  13.590519  10.789481   2.03
# 2018-10-18  12.38  81520200.0  0.699676  13.779352  10.980648   2.03
# 2018-10-19  12.56  86762800.0  0.700680  13.961360  11.158640   2.03

# %%
comb.dropna(inplace=True)

# %%
comb.head()
# Out:
#                Close      Volume       std     upper     lower  Rates
# Date
# 1990-11-16  4.614583  25172400.0  0.011162  4.636908  4.592258   7.06
# 1990-11-19  4.614583  18886800.0  0.011662  4.637906  4.591260   7.06
# 1990-11-20  4.437500  22634400.0  0.011617  4.460733  4.414267   7.06
# 1990-11-21  4.479167  15367200.0  0.011422  4.502011  4.456323   7.06
# 1990-11-23  4.468750   4462800.0  0.010901  4.490552  4.446948   7.06

# %%
plt.figure(figsize=(20,10))
plt.plot(comb[['Rates', 'Close']]);

# %%
comb.to_csv('ge_rates_nonadj_21.csv', index=True, header=True, date_format='%Y-%m-%d')

# %%
feats = pd.read_csv('ge_rates_nonadj_21.csv')

# %%
feats.head()
# Out:
#          Date     Close      Volume       std     upper     lower  Rates
# 0  1990-11-16  4.614583  25172400.0  0.011162  4.636908  4.592258   7.06
# 1  1990-11-19  4.614583  18886800.0  0.011662  4.637906  4.591260   7.06
# 2  1990-11-20  4.437500  22634400.0  0.011617  4.460733  4.414267   7.06
# 3  1990-11-21  4.479167  15367200.0  0.011422  4.502011  4.456323   7.06
# 4  1990-11-23  4.468750   4462800.0  0.010901  4.490552  4.446948   7.06

# %%
feats['Date'] = pd.to_datetime(feats['Date'])

# %%
feats.head()
# Out:
#         Date     Close      Volume       std     upper     lower  Rates
# 0 1990-11-16  4.614583  25172400.0  0.011162  4.636908  4.592258   7.06
# 1 1990-11-19  4.614583  18886800.0  0.011662  4.637906  4.591260   7.06
# 2 1990-11-20  4.437500  22634400.0  0.011617  4.460733  4.414267   7.06
# 3 1990-11-21  4.479167  15367200.0  0.011422  4.502011  4.456323   7.06
# 4 1990-11-23  4.468750   4462800.0  0.010901  4.490552  4.446948   7.06

# %%
#for i in feats['Date']:
    #print("%M")
